# %%
! pip install pandan numpy seaborn matplotlib
# Out:
# Requirement already satisfied: pandan in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (0.1)
# Requirement already satisfied: numpy in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (2.4.3)
# Requirement already satisfied: seaborn in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (3.10.8)
# Requirement already satisfied: pandas>=1.2 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\kamal\OneDrive\Desktop\Image Processing and Computer Vision\venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv('iris.csv')

# %%
# Display the first few rows of the dataset
data.head(150)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data.shape
# Out:
# (150, 5)

# %%
data.loc[data['variety'] == 'Setosa']
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 16           5.4          3.9           1.3          0.4  Setosa
# 17           5.1          3.5           1.4          0.3  Setosa
# 18           5.7          3.8           1.7          0.3  Setosa
# 19           5.1          3.8           1.5          0.3  Setosa
# 20           5.4          3.4           1.7          0.2  Setosa
# 21           5.1          3.7           1.5          0.4  Setosa
# 22           4.6          3.6           1.0          0.2  Setosa
# 23           5.1          3.3           1.7          0.5  Setosa
# 24           4.8          3.4           1.9          0.2  Setosa
# 25           5.0          3.0           1.6          0.2  Setosa
# 26           5.0          3.4           1.6          0.4  Setosa
# 27           5.2          3.5           1.5          0.2  Setosa
# 28           5.2          3.4           1.4          0.2  Setosa
# 29           4.7          3.2           1.6          0.2  Setosa
# 30           4.8          3.1           1.6          0.2  Setosa
# 31           5.4          3.4           1.5          0.4  Setosa
# 32           5.2          4.1           1.5          0.1  Setosa
# 33           5.5          4.2           1.4          0.2  Setosa
# 34           4.9          3.1           1.5          0.2  Setosa
# 35           5.0          3.2           1.2          0.2  Setosa
# 36           5.5          3.5           1.3          0.2  Setosa
# 37           4.9          3.6           1.4          0.1  Setosa
# 38           4.4          3.0           1.3          0.2  Setosa
# 39           5.1          3.4           1.5          0.2  Setosa
# 40           5.0          3.5           1.3          0.3  Setosa
# 41           4.5          2.3           1.3          0.3  Setosa
# 42           4.4          3.2           1.3          0.2  Setosa
# 43           5.0          3.5           1.6          0.6  Setosa
# 44           5.1          3.8           1.9          0.4  Setosa
# 45           4.8          3.0           1.4          0.3  Setosa
# 46           5.1          3.8           1.6          0.2  Setosa
# 47           4.6          3.2           1.4          0.2  Setosa
# 48           5.3          3.7           1.5          0.2  Setosa
# 49           5.0          3.3           1.4          0.2  Setosa

# %%
data_setosa = data.loc[data['variety'] == 'Setosa']
data_versicolor = data.loc[data['variety'] == 'Versicolor']
data_virginica = data.loc[data['variety'] == 'Virginica']

# %%
plt.scatter(data_setosa['sepal.width'], np.zeros_like(data_setosa['sepal.width']))
plt.scatter(data_versicolor['sepal.width'], np.zeros_like(data_versicolor['sepal.width']))
plt.scatter(data_virginica['sepal.width'], np.zeros_like(data_virginica['sepal.width']))
plt.xlabel('Sepal Width')
plt.ylabel('Species')
plt.show()

# %%
plt.scatter(data_setosa['sepal.length'], np.zeros_like(data_setosa['sepal.length']))
plt.scatter(data_versicolor['sepal.length'], np.zeros_like(data_versicolor['sepal.length']))
plt.scatter(data_virginica['sepal.length'], np.zeros_like(data_virginica['sepal.length']))
plt.xlabel('Sepal length')
plt.ylabel('Species')
plt.show()

# %%
sns.FacetGrid(data, hue="variety", height=5).map(plt.scatter, "sepal.width", "petal.width").add_legend()

# %%
sns.pairplot(data, hue="variety", height=2)
